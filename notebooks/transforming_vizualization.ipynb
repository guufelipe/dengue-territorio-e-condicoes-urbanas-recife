# %%
# ==============================
# Setup de ambiente do notebook
# ==============================
import sys
from pathlib import Path
import pandas as pd

# %%
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent

NOTEBOOK_DIR, PROJECT_ROOT
# Out:
# (WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/notebooks'),
#  WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife'))

# %%
(PROJECT_ROOT / "data").exists(), list((PROJECT_ROOT / "data").iterdir())
# Out:
# (True,
#  [WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/analytics'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/processed'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw')])

# %%
(PROJECT_ROOT / "data" / "raw").exists(), list((PROJECT_ROOT / "data" / "raw").iterdir())
# Out:
# (True,
#  [WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/chikungunya'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/demografia'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/metadados'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/saneamento'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/tabelas_auxiliares'),
#   WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/zika')])

# %%
for agravo in ["dengue", "zika", "chikungunya"]:
    path = PROJECT_ROOT / "data" / "raw" / agravo
    print(agravo, "-> existe?", path.exists())
# Out:
# dengue -> existe? True
# zika -> existe? True
# chikungunya -> existe? True

# %%
dengue_path = PROJECT_ROOT / "data" / "raw" / "dengue"
list(dengue_path.glob("*.csv"))
# Out:
# [WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue/dengon-2021-ok.csv'),
#  WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue/dengon-2022.csv'),
#  WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue/dengon-2023-ok-1.csv'),
#  WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue/dengon-2024.csv'),
#  WindowsPath('C:/Users/gfasg/OneDrive/Área de Trabalho/Projeto Dengue/dengue-territorio-e-condicoes-urbanas-recife/data/raw/dengue/dengon2020_recife.csv')]

# %%
import sys

sys.path.insert(0, str(PROJECT_ROOT))
sys.path[:3]
# Out:
# ['C:\\Users\\gfasg\\OneDrive\\Área de Trabalho\\Projeto Dengue\\dengue-territorio-e-condicoes-urbanas-recife',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\python311.zip',
#  'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\\DLLs']

# %%
from src.transform.join_tables import join_agravo_years

join_agravo_years
# Out:
# <function src.transform.join_tables.join_agravo_years(agravo: str, base_path: pathlib.Path, sep: str = ';', encoding: str = 'latin1') -> pandas.core.frame.DataFrame>

# %%
df_dengue = join_agravo_years(
    agravo="dengue",
    base_path=PROJECT_ROOT / "data" / "raw"
)

df_dengue.shape
df_dengue.head()
# Out:
#    ï»¿NU_NOTIFIC  TP_NOT ID_AGRAVO  DT_NOTIFIC   SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0      3730655.0     2.0       A90  01/01/2021  202053.0  2021.0       26.0
# 1      3730656.0     2.0       A90  01/01/2021  202053.0  2021.0       26.0
# 2      3730652.0     2.0       A90  01/01/2021  202053.0  2021.0       26.0
# 3      3730657.0     2.0       A90  01/01/2021  202053.0  2021.0       26.0
# 4      4197902.0     2.0       A90  01/01/2021  202053.0  2021.0       26.0
#
#    ID_MUNICIP  ID_REGIONA  ID_UNIDADE  ... co_pais_infeccao  \
# 0    261160.0      1497.0       671.0  ...              NaN
# 1    261160.0      1497.0       671.0  ...              NaN
# 2    261160.0      1497.0       671.0  ...              NaN
# 3    261160.0      1497.0       671.0  ...              NaN
# 4    261160.0      1497.0       590.0  ...              NaN
#
#    co_municipio_infeccao co_distrito_infeccao  co_bairro_infeccao  \
# 0                    NaN                  NaN                 NaN
# ...

# %%
df_zika = join_agravo_years(
    agravo="zika",
    base_path=PROJECT_ROOT / "data" / "raw"
)

df_zika.shape
df_zika.head()
# Out:
#    NU_NOTIFIC  TP_NOT ID_AGRAVO  CS_SUSPEIT  DT_NOTIFIC   SEM_NOT  NU_ANO  \
# 0   3716012.0     2.0      A928         NaN  2021-01-11  202102.0  2021.0
# 1   3725134.0     2.0      A928         NaN  2021-01-27  202104.0  2021.0
# 2   3762467.0     2.0      A928         NaN  2021-02-04  202105.0  2021.0
# 3   3802872.0     2.0      A928         NaN  2021-02-10  202106.0  2021.0
# 4   3908667.0     2.0      A928         NaN  2021-04-28  202117.0  2021.0
#
#    SG_UF_NOT  ID_MUNICIP  ID_REGIONA  ...  co_uf_infeccao co_pais_infeccao  \
# 0       26.0    261160.0      1497.0  ...             NaN              NaN
# 1       26.0    261160.0      1497.0  ...             NaN              NaN
# 2       26.0    261160.0      1497.0  ...             NaN              NaN
# 3       26.0    260290.0      1497.0  ...             NaN              NaN
# 4       26.0    261160.0      1497.0  ...             NaN              NaN
#
#    co_municipio_infeccao co_distrito_infeccao  co_bairro_infeccao  \
# ...

# %%
df_chik = join_agravo_years(
    agravo="chikungunya",
    base_path=PROJECT_ROOT / "data" / "raw"
)

df_chik.shape
df_chik.head()
# Out:
#    ï»¿NU_NOTIFIC  TP_NOT ID_AGRAVO  DT_NOTIFIC   SEM_NOT  NU_ANO  SG_UF_NOT  \
# 0      3730663.0     2.0     A92.0  01/01/2021  202053.0  2021.0       26.0
# 1      3730659.0     2.0     A92.0  01/01/2021  202053.0  2021.0       26.0
# 2      3730662.0     2.0     A92.0  01/01/2021  202053.0  2021.0       26.0
# 3      3730664.0     2.0     A92.0  02/01/2021  202053.0  2021.0       26.0
# 4      3730665.0     2.0     A92.0  02/01/2021  202053.0  2021.0       26.0
#
#    ID_MUNICIP  ID_REGIONA  ID_UNIDADE  ... petequias  hematura sangram  \
# 0    261160.0      1497.0       671.0  ...       NaN       NaN     NaN
# 1    261160.0      1497.0       671.0  ...       NaN       NaN     NaN
# 2    261160.0      1497.0       671.0  ...       NaN       NaN     NaN
# 3    261160.0      1497.0       671.0  ...       NaN       NaN     NaN
# 4    261160.0      1497.0       671.0  ...       NaN       NaN     NaN
#
#    laco_n plasmatico  evidencia  plaq_menor  con_fhd  complica  NU_NOTIFIC
# ...

# %%
from src.transform.select_columns import (
    tratar_dados_dengue,
    tratar_dados_zika,
    tratar_dados_chikungunya
)

df_dengue_sel = tratar_dados_dengue(df_dengue)
df_zika_sel = tratar_dados_zika(df_zika)
df_chik_sel = tratar_dados_chikungunya(df_chik)

df_chik_sel.head(10)
# Out:
#    num_notificacao dt_notificacao  co_municipio_notificacao  \
# 0              NaN     01/01/2021                  261160.0
# 1              NaN     01/01/2021                  261160.0
# 2              NaN     01/01/2021                  261160.0
# 3              NaN     02/01/2021                  261160.0
# 4              NaN     02/01/2021                  261160.0
# 5              NaN     02/01/2021                  261160.0
# 6              NaN     03/01/2021                  261160.0
# 7              NaN     03/01/2021                  261160.0
# 8              NaN     04/01/2021                  261160.0
# 9              NaN     04/01/2021                  261160.0
#
#    co_unidade_notificacao dt_nascimento sexo  gestante  raca_cor  \
# 0                   671.0    1972-08-22    F       9.0       9.0
# 1                   671.0    1961-05-12    F       9.0       9.0
# 2                   671.0    1981-07-26    F       9.0       9.0
# ...
